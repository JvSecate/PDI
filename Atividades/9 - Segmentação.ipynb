# %% [markdown]
# ##Atividade Segmentação

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def laplacian_interest_points(imagem):
  gray_image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
  laplacian = cv2.Laplacian(gray_image, cv2.CV_64F)
  laplacian_abs = cv2.convertScaleAbs(laplacian)
  keypoints = cv2.goodFeaturesToTrack(laplacian_abs, maxCorners=100, qualityLevel=0.01, minDistance=10)
  return gray_image, laplacian_abs, keypoints

img2 = cv2.imread(imagem3)
img = cv2.imread(imagem2)

gray_image, laplacian_image, keypoints = laplacian_interest_points(img)
gray_image2, laplacian_image2, keypoints2 = laplacian_interest_points(img2)
laplaciano = cv2.Laplacian(img, cv2.CV_64F)
laplaciano2 = cv2.Laplacian(img2, cv2.CV_64F)
threshold_value = 10

_, laplacian_thres = cv2.threshold(np.abs(laplaciano),
threshold_value, 255, cv2.THRESH_BINARY)
_, laplacian_thres2 = cv2.threshold(np.abs(laplaciano2),
threshold_value, 255, cv2.THRESH_BINARY)
gaussian_blur = cv2.GaussianBlur(img, (5, 5), 1)
gaussian_blur2 = cv2.GaussianBlur(img2, (5, 5), 1)
T5, T6 = 20 , 25

edges_cannyy = cv2.Canny(gaussian_blur, T5, T6)
edges_cannyy2 = cv2.Canny(gaussian_blur2, T5, T6)

plt.figure(figsize=(20, 10))
plt.subplot(1, 3, 1)
plt.title('Imagem Original')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.subplot(1, 3, 2)
plt.title('Imagem Laplaciana')
plt.imshow(laplacian_image, cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.title('Imagem Limiar')
plt.imshow(cv2.cvtColor(edges_cannyy, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.figure(figsize=(20, 10))
plt.subplot(1, 3, 1)
plt.title('Imagem Original')
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.subplot(1, 3, 2)
plt.title('Imagem Laplaciana')
plt.imshow(laplacian_image2, cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.title('Imagem Limiar')
plt.imshow(cv2.cvtColor(edges_cannyy2, cv2.COLOR_BGR2RGB))
plt.axis('off')

laplacian = cv2.Laplacian(image, cv2.CV_64F)
threshold_value = 10
_, laplacian_thresh = cv2.threshold(np.abs(laplacian),
threshold_value, 255, cv2.THRESH_BINARY)
gaussian_blur = cv2.GaussianBlur(image, (5, 5), 1)
T1, T2 ,T3 ,T4 = 50, 150 , 100 , 200
edges_canny = cv2.Canny(gaussian_blur, T1, T2)
edges_canny_updated = cv2.Canny(gaussian_blur, T1, T2)
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))
ax[0,0].imshow(image, cmap='gray')
ax[0,0].set_title('Imagem original')
ax[0,0].axis('off')
ax[0,1].imshow(laplacian, cmap='gray')
ax[0,1].set_title('Laplaciano')
ax[0,1].axis('off')
ax[0,2].imshow(laplacian_thresh, cmap='gray')
ax[0,2].set_title('Limiarização do laplaciano')
ax[0,2].axis('off')
ax[1,0].imshow(gaussian_blur, cmap='gray')
ax[1,0].set_title('Borramento do Gaussiano')
ax[1,0].axis('off')
ax[1,1].imshow(edges_canny, cmap='gray')
ax[1,1].set_title('Detecção de Bordas Canny (50 e 150)')
ax[1,1].axis('off')
ax[1,2].imshow(edges_canny_updated, cmap='gray')
ax[1,2].set_title('Detecção de Bordas Canny (100 e 200)')
ax[1,2].axis('off')
